# %%
import os
os.environ['MLFLOW_TRACKING_URI']="file:///Users/HP/OneDrive/Documents/Bhuvan/b"

# %%
import mlflow
all_runs = mlflow.search_runs(search_all_experiments=True)
print(all_runs)
# Out:
#                               run_id       experiment_id    status  \
# 0   6e5974429b054cecb15949ed6fd79155  555404616607289668  FINISHED
# 1   10a823cf7b304a4ebd6bf9ca05578296  555404616607289668  FINISHED
# 2   360331a9e04e452c82abb25c304a17c2  884508345532141847  FINISHED
# 3   fa92e230f5b041e4b3e3d8be88a3d15c  884508345532141847  FINISHED
# 4   d94149a4ad2048ceb03d0d22bdb2bfcc  884508345532141847    FAILED
# 5   d539906b452e47639e2d75c32e6a39b4  884508345532141847    FAILED
# 6   48603ae2bf634c0dabc5b08e33224d06  884508345532141847    FAILED
# 7   5d52d6e3769347f5ba1cce907c465ae5  884508345532141847    FAILED
# 8   2ad78badd2b347d8922eef8081bf2c96  884508345532141847    FAILED
# 9   a09bc9e481e44f98a071a0f037991e8f  641102873895942447  FINISHED
# 10  480319a1e58841089b30f172cbc83d3f  641102873895942447    FAILED
#
#                                          artifact_uri  \
# 0   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 1   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 2   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 3   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 4   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 5   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 6   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 7   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 8   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 9   file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
# 10  file:///C:/Users/HP/OneDrive/Documents/Bhuvan/...
#
#                          start_time                         end_time  \
# 0  2024-07-18 11:07:21.505000+00:00 2024-07-18 11:08:10.394000+00:00
# 1  2024-07-18 11:04:02.888000+00:00 2024-07-18 11:04:57.804000+00:00
# 2  2024-07-17 13:22:37.495000+00:00 2024-07-17 13:25:48.397000+00:00
# 3  2024-07-17 12:46:55.241000+00:00 2024-07-17 12:50:11.859000+00:00
# 4  2024-07-17 12:44:55.360000+00:00 2024-07-17 12:46:45.903000+00:00
# 5  2024-07-17 12:41:32.431000+00:00 2024-07-17 12:41:32.572000+00:00
# 6  2024-07-17 12:40:13.891000+00:00 2024-07-17 12:40:14.082000+00:00
# 7  2024-07-17 12:39:55.907000+00:00 2024-07-17 12:39:56.052000+00:00
# 8  2024-07-17 12:39:28.711000+00:00 2024-07-17 12:39:29.143000+00:00
# 9  2024-07-17 12:11:36.575000+00:00 2024-07-17 12:12:25.145000+00:00
# 10 2024-07-17 12:10:31.130000+00:00 2024-07-17 12:11:01.411000+00:00
#
#     metrics.rf_testing_score  metrics.rf_training_score  \
# 0                  -0.134140                   0.801101
# 1                  -0.133072                   0.801554
# 2                        NaN                 -33.155687
# 3                        NaN                 -33.007477
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                   1.000000
# 10                       NaN                   1.000000
#
#     metrics.gbm_training_score  metrics.gbm_testing_score  ...  \
# 0                     0.999997                  -0.078308  ...
# 1                     0.999997                  -0.082311  ...
# 2                    -4.394614                        NaN  ...
# 3                    -4.389372                        NaN  ...
# 4                          NaN                        NaN  ...
# 5                          NaN                        NaN  ...
# 6                          NaN                        NaN  ...
# 7                          NaN                        NaN  ...
# 8                          NaN                        NaN  ...
# 9                     1.000000                        NaN  ...
# 10                    1.000000                        NaN  ...
#
#    params.gbm_max_depth params.gbm_learning_rate params.n_estimators  \
# 0                     6                     0.01                5000
# 1                     6                     0.01                5000
# 2                     6                     0.01                5000
# 3                     6                     0.01                5000
# 4                     6                     0.01                5000
# 5                     6                     0.01                5000
# 6                     6                     0.01                5000
# 7                     6                     0.01                5000
# 8                     6                     0.01                5000
# 9                     6                     0.01                5000
# 10                    6                     0.01                5000
#
#    params.gbm_n_estimators params.gbm_minimum_samples_split tags.mlflow.user  \
# 0                     3000                                5               HP
# 1                     3000                                5               HP
# 2                     3000                                5               HP
# 3                     3000                                5               HP
# 4                     3000                                5               HP
# 5                     3000                                5               HP
# 6                     3000                                5               HP
# 7                     3000                                5               HP
# 8                     3000                                5               HP
# 9                     3000                                5               HP
# 10                    3000                                5               HP
#
#    tags.mlflow.source.type                      tags.mlflow.log-model.history  \
# 0                    LOCAL  [{"run_id": "6e5974429b054cecb15949ed6fd79155"...
# 1                    LOCAL  [{"run_id": "10a823cf7b304a4ebd6bf9ca05578296"...
# 2                    LOCAL  [{"run_id": "360331a9e04e452c82abb25c304a17c2"...
# 3                    LOCAL  [{"run_id": "fa92e230f5b041e4b3e3d8be88a3d15c"...
# 4                    LOCAL                                               None
# 5                    LOCAL                                               None
# 6                    LOCAL                                               None
# 7                    LOCAL                                               None
# 8                    LOCAL                                               None
# 9                    LOCAL  [{"run_id": "a09bc9e481e44f98a071a0f037991e8f"...
# 10                   LOCAL                                               None
#
#    tags.mlflow.runName                            tags.mlflow.source.name
# 0    debonair-worm-291  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 1    charming-hawk-441  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 2   honorable-wolf-548  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 3    fearless-lark-726  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 4    legendary-bee-607  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 5   indecisive-bee-827  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 6    shivering-eel-826  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 7     capable-shad-706  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 8    dashing-steed-983  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 9       kindly-pug-631  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
# 10  enthused-smelt-559  C:\Users\HP\anaconda3\Lib\site-packages\ipyker...
#
# [11 rows x 21 columns]

# %%
# !mlflow models serve -p 1023 -m runs:/6e5974429b054cecb15949ed6fd79155/random-forest-model --no-conda
