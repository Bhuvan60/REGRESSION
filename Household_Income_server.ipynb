# %%
import os
os.environ['MLFLOW_TRACKING_URI']="file:///Users/HP/OneDrive/Documents/Bhuvan/b"

# %%
import mlflow
all_runs = mlflow.search_runs(search_all_experiments=True)
print(all_runs)
# Out:
#                               run_id       experiment_id    status  \
# 0   7be1ecee4a7145e5be2e14ab7f2138c8  884508345532141847  FINISHED
# 1   eeeb63e0151141379ab29c2bff2d5242  884508345532141847  FINISHED
# 2   c8088945ff4e46b4ae830163713ff3c5  884508345532141847  FINISHED
# 3   e6fb43df85914eb99b6bf2104bb3251d  884508345532141847  FINISHED
# 4   1249b13c61fd4a5985013960ed2506ee  555404616607289668  FINISHED
# 5   6e5974429b054cecb15949ed6fd79155  555404616607289668  FINISHED
# 6   10a823cf7b304a4ebd6bf9ca05578296  555404616607289668  FINISHED
# 7   360331a9e04e452c82abb25c304a17c2  884508345532141847  FINISHED
# 8   fa92e230f5b041e4b3e3d8be88a3d15c  884508345532141847  FINISHED
# 9   d94149a4ad2048ceb03d0d22bdb2bfcc  884508345532141847    FAILED
# 10  d539906b452e47639e2d75c32e6a39b4  884508345532141847    FAILED
# 11  48603ae2bf634c0dabc5b08e33224d06  884508345532141847    FAILED
# 12  5d52d6e3769347f5ba1cce907c465ae5  884508345532141847    FAILED
# ...

# %%
# !mlflow models serve -p 8003 -m runs:/c8088945ff4e46b4ae830163713ff3c5/random-forest-model --no-conda
